# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn import tree
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
dataset = load_iris()
X, y = dataset.data, dataset.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
classifier = tree.DecisionTreeClassifier()

# %%
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = classifier.predict(X_test)

accuracy_score(y_test, y_predict)
# Out:
# 0.9333333333333333

# %%
result = classifier.predict([[4, 3, 1, 0]])
print(dataset.target_names[result])
# Out:
# ['setosa']

# %%
tree.plot_tree(classifier)
# Out:
# [Text(0.4444444444444444, 0.9, 'x[2] <= 2.45\ngini = 0.666\nsamples = 105\nvalue = [35, 34, 36]'),
#  Text(0.3333333333333333, 0.7, 'gini = 0.0\nsamples = 35\nvalue = [35, 0, 0]'),
#  Text(0.5555555555555556, 0.7, 'x[3] <= 1.75\ngini = 0.5\nsamples = 70\nvalue = [0, 34, 36]'),
#  Text(0.3333333333333333, 0.5, 'x[2] <= 5.35\ngini = 0.153\nsamples = 36\nvalue = [0, 33, 3]'),
#  Text(0.2222222222222222, 0.3, 'x[0] <= 4.95\ngini = 0.057\nsamples = 34\nvalue = [0, 33, 1]'),
#  Text(0.1111111111111111, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.3333333333333333, 0.1, 'gini = 0.0\nsamples = 33\nvalue = [0, 33, 0]'),
#  Text(0.4444444444444444, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.7777777777777778, 0.5, 'x[2] <= 4.85\ngini = 0.057\nsamples = 34\nvalue = [0, 1, 33]'),
#  Text(0.6666666666666666, 0.3, 'x[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.5555555555555556, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.7777777777777778, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8888888888888888, 0.3, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 31]')]

# %%
import matplotlib.pyplot as plt

print(y_test, y_predict)
plt.scatter(y_test, y_predict, alpha=0.7, color='blue')
plt.title('Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# [1 0 2 1 0 2 0 0 0 1 1 2 2 2 1 0 0 0 1 2 2 2 0 2 2 1 2 1 0 1 1 0 0 1 1 1 2
#  1 0 1 2 2 0 0 1] [1 0 2 1 0 2 0 0 0 1 1 2 1 2 1 0 0 0 1 2 2 2 0 2 2 2 2 1 0 1 1 0 0 1 1 1 2
#  1 0 1 2 1 0 0 1]
